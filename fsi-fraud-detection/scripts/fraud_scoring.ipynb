# %% [markdown]
# # Fraud Scoring Engine
# Scores new transactions for fraud using the trained ML model.

# %%
import os
import sys
sys.path.insert(0, '.')

# Import the scoring function
exec(open('03_score_new_transactions.py').read())

# Run one batch
print('Running fraud scoring batch...')
scored = score_batch()
print(f'Successfully scored {scored} transactions')
